# %%
from ncn.evaluation import Evaluator
from ncn.data import get_datasets
import numpy as np

# %%
#path_to_weights = "./models/NCN_9_4_4_128_filters.pt"
path_to_weights = "../models/NCN_9_4_4_128_filters_org.pt"
#path_to_data = "/home/jupyter/tutorials/seminar_kd/arxiv_data.csv"
path_to_data = "ncn/arxiv_data.csv"
data = get_datasets(path_to_data, 20000, 20000, 20000)
# Out:
# INFO:ncn.data:Getting fields...
# INFO:ncn.data:Loading dataset...
# INFO:ncn.data:Building vocab...

# %%
evaluator = Evaluator([4,4,5,6,7], [1,2], 128, 128, 2, path_to_weights, data, evaluate=True, show_attention=False)
# Out:
# INFO:ncn.evaluation:INITIALIZING NEURAL CITATION NETWORK WITH AUTHORS = True
# Running on: cpu
# Number of model parameters: 16,728,996
# Encoders: # Filters = 128, Context filter length = [4, 4, 5, 6, 7],  Context filter length = [1, 2]
# Embeddings: Dimension = 128, Pad index = 1, Context vocab = 20002, Author vocab = 20002, Title vocab = 20004
# Decoder: # GRU cells = 2, Hidden size = 128
# Parameters: Dropout = 0.2, Show attention = False
# -------------------------------------------------
# INFO:ncn.evaluation:Creating corpus in eval=True mode.
# INFO:ncn.evaluation:Number of samples in BM25 corpus: 50235

# %%
at_10 = evaluator.recall(10)
# Out:
#   0%|          | 0/20000 [00:00<?, ?it/s]
# 2, 110, 113])
# INFO:ncn.evaluation:Lowest scores: tensor([11.0746, 13.4565, 16.9256, 17.3751, 18.3287, 20.2674, 21.0947, 22.2221,
#         22.3418, 23.0115])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([260])
# INFO:ncn.evaluation:Index: tensor([38, 58, 26, 64, 88, 63, 61, 59, 93, 57])
# INFO:ncn.evaluation:Lowest scores: tensor([12.0699, 12.3692, 12.8526, 18.8053, 21.8790, 22.4545, 23.2295, 24.4391,
#         24.7926, 28.0880])
# INFO:ncn.evaluation:Range of true titles: 259 - 255
# INFO:ncn.evaluation:Scored 0 out of 4 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([ 17, 166, 181, 242, 172, 169,  88, 167, 115, 117])
# INFO:ncn.evaluation:Lowest scores: tensor([ 8.0555, 15.9272, 16.5599, 17.2872, 18.5678, 18.7429, 19.6317, 20.5416,
#         20.6904, 23.0551])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([215, 124,  76, 221,  70,  77, 123,  73, 201, 212])
# INFO:ncn.evaluation:Lowest scores: tensor([ 9.1827, 11.7806, 12.3191, 13.6956, 14.0590, 14.0911, 14.4757, 15.2945,
#         15.3781, 15.4348])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([ 94, 102, 208, 155, 193,   9, 213,  36, 152,  56])
# INFO:ncn.evaluation:Lowest scores: tensor([ 7.1190, 12.9326, 13.9230, 14.5931, 14.6991, 15.1463, 15.8825, 16.3853,
#         16.9399, 16.9593])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([ 12,  29, 246, 153,  48, 121,  96,  78, 105,  31])
# INFO:ncn.evaluation:Lowest scores: tensor([ 9.2238,  9.3804, 10.6189, 11.5274, 11.5880, 11.7309, 12.7320, 12.7410,
#         13.1239, 13.5455])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([133, 195, 206, 191,   7, 110, 238,  17, 227, 200])
# INFO:ncn.evaluation:Lowest scores: tensor([11.8215, 11.9720, 12.0206, 13.1152, 13.9403, 14.9460, 14.9692, 15.3359,
#         15.7042, 15.7081])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([ 19, 153, 173,   7,  74,  22,   8,   4,  78, 129])
# INFO:ncn.evaluation:Lowest scores: tensor([ 7.8492, 11.7692, 11.8333, 13.0868, 13.2780, 14.0878, 15.3477, 17.2415,
#         17.4680, 19.4985])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([240,  82,  81, 245, 212, 132, 228,  61, 227, 182])
# INFO:ncn.evaluation:Lowest scores: tensor([ 8.9362,  8.9799, 10.5788, 11.3120, 12.0820, 12.1482, 12.4289, 12.6141,
#         13.3668, 13.4951])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([  1,  21, 161, 167,  41,  27,  51, 139, 122,  71])
# INFO:ncn.evaluation:Lowest scores: tensor([ 8.2293, 11.3717, 12.5366, 12.6514, 16.2325, 16.6385, 16.9051, 17.3097,
#         17.3682, 17.5242])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([219, 218, 243,  77,  92, 175,  70,   6, 118,  46])
# INFO:ncn.evaluation:Lowest scores: tensor([ 8.1983,  9.9709, 11.3253, 12.1893, 12.2396, 15.2936, 15.5177, 18.8730,
#         21.6859, 21.9383])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([ 13, 121,  55,  12,  14, 140, 204, 250, 134,  29])
# INFO:ncn.evaluation:Lowest scores: tensor([ 9.0945, 11.7155, 12.3201, 12.4002, 12.8890, 13.6422, 15.8914, 16.3788,
#         17.5556, 18.8444])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([238, 110, 192, 241, 111,  52,  73, 193,  37,  21])
# INFO:ncn.evaluation:Lowest scores: tensor([ 7.8491, 13.8355, 14.6571, 14.6714, 15.6159, 15.8317, 17.7939, 18.9969,
#         20.2667, 24.4776])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([  8, 236, 123,  57, 140,   1,   4,  96,  62,  59])
# INFO:ncn.evaluation:Lowest scores: tensor([ 8.7898,  9.4832, 11.0499, 11.4720, 11.5560, 14.1721, 14.2003, 15.0491,
#         15.6096, 16.6450])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([160,  71, 246,  80, 244, 126, 211, 199,  65, 253])
# INFO:ncn.evaluation:Lowest scores: tensor([ 7.0860,  7.2533,  7.5752,  7.9352,  8.8411,  9.2039, 10.8815, 11.0441,
#         11.1015, 11.1394])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([ 70, 138, 152, 180,   3,  18, 149, 178, 237, 177])
# INFO:ncn.evaluation:Lowest scores: tensor([ 9.9064, 12.7624, 13.0631, 13.6838, 15.1228, 15.5683, 16.0237, 16.5420,
#         17.0734, 20.0987])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([ 92, 126, 168,  55, 135,  15, 185, 194, 122,  97])
# INFO:ncn.evaluation:Lowest scores: tensor([10.2952, 11.3522, 12.1497, 12.3551, 12.4963, 12.5860, 13.7850, 14.0124,
#         15.0845, 15.5599])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([132,  16,   3,  66, 135,  54, 177, 178,  65, 136])
# INFO:ncn.evaluation:Lowest scores: tensor([ 9.1291, 11.3054, 12.5870, 15.7802, 16.1266, 16.8280, 16.8325, 17.4679,
#         18.5023, 20.2064])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([256,  58,  99, 163, 121,  66, 185, 240, 233, 137])
# INFO:ncn.evaluation:Lowest scores: tensor([ 5.9698,  9.1512,  9.3352, 10.6794, 11.0649, 11.2332, 11.2557, 12.1558,
#         13.1068, 13.6466])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 1 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([169,  73, 158, 161,  96, 105, 239, 254, 247, 116])
# INFO:ncn.evaluation:Lowest scores: tensor([ 7.4076,  7.5835,  8.7416, 10.4123, 10.8929, 10.8947, 11.0296, 11.5015,
#         11.7941, 11.9083])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([150, 207, 223, 196,  59, 247, 147,  37, 155, 240])
# INFO:ncn.evaluation:Lowest scores: tensor([ 8.8802,  8.9348,  9.1085, 10.1549, 10.3309, 11.0016, 12.4979, 13.3000,
#         13.9749, 14.3070])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([120,  70, 111, 247, 233,  92, 112, 254, 199,   6])
# INFO:ncn.evaluation:Lowest scores: tensor([10.6812, 11.7088, 12.3609, 12.5608, 14.7443, 16.4762, 18.6067, 19.3448,
#         20.3681, 22.0102])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([ 82, 174, 256,  99,  54, 226,  94, 255,  42, 159])
# INFO:ncn.evaluation:Lowest scores: tensor([ 8.8567,  9.6635,  9.9382, 10.4558, 10.5606, 10.8982, 11.2187, 11.2540,
#         11.4254, 11.9694])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 1 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([258])
# INFO:ncn.evaluation:Index: tensor([  0, 256,  15, 253,  14,   7,  80, 228,  74,  11])
# INFO:ncn.evaluation:Lowest scores: tensor([ 8.1196,  8.1705,  9.7895, 10.7969, 12.1277, 12.3751, 12.9047, 13.1938,
#         13.4494, 14.5346])
# INFO:ncn.evaluation:Range of true titles: 257 - 255
# INFO:ncn.evaluation:Scored 1 out of 2 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([ 48,  68,  62,  19,  22,   6, 217,  30, 116, 162])
# INFO:ncn.evaluation:Lowest scores: tensor([ 8.1750,  9.6817, 10.7280, 12.8499, 13.5705, 14.6698, 14.7040, 15.8289,
#         17.3457, 18.0275])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([118, 116,  13,  23,  22,  26,  18, 255, 195, 103])
# INFO:ncn.evaluation:Lowest scores: tensor([ 6.5898,  9.0735, 11.6670, 15.7913, 17.1830, 17.8002, 17.8381, 18.6386,
#         19.2953, 20.3846])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([ 45,  92, 174, 159, 127,  69, 120, 226, 175,  63])
# INFO:ncn.evaluation:Lowest scores: tensor([ 7.4501,  8.0855,  8.5476,  9.3403, 11.3254, 11.9508, 12.0670, 12.1071,
#         12.2265, 12.3587])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([ 41, 153, 155,  25,  29, 239,  75, 162, 126, 235])
# INFO:ncn.evaluation:Lowest scores: tensor([ 7.9830,  8.2453,  8.6451,  9.2707,  9.4023,  9.7616, 10.3877, 11.0527,
#         11.6675, 12.3039])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([151,  70,  76, 122, 117, 140, 107, 245,  82,  50])
# INFO:ncn.evaluation:Lowest scores: tensor([12.9998, 13.1670, 13.8834, 14.6145, 14.7134, 14.8053, 14.8974, 15.5152,
#         16.0495, 16.7539])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([129, 236, 208,  91, 165, 233,  44, 161, 123,  12])
# INFO:ncn.evaluation:Lowest scores: tensor([ 9.5003, 10.0690, 11.2337, 11.5915, 14.3124, 15.1922, 15.2352, 16.5837,
#         16.7825, 16.8650])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([184,  88,  74,  20,  44, 183, 111, 252, 172, 157])
# INFO:ncn.evaluation:Lowest scores: tensor([ 8.7139,  9.8512,  9.9849, 11.3020, 11.7942, 13.3515, 13.6791, 15.5689,
#         15.9045, 17.2868])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([256, 140, 152, 144, 120, 161, 184,  50, 191,  45])
# INFO:ncn.evaluation:Lowest scores: tensor([ 8.4107,  9.4583,  9.5993, 11.2242, 12.8597, 12.8718, 14.9333, 15.6952,
#         16.0418, 16.2963])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 1 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([ 61, 108, 214, 145,  82, 166,  66, 110,  65, 197])
# INFO:ncn.evaluation:Lowest scores: tensor([ 6.2130,  8.9232,  9.7289, 10.1274, 10.8761, 11.2526, 11.8615, 12.3408,
#         12.4096, 13.8167])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([188, 128, 202, 205, 167, 215, 249, 124, 227, 104])
# INFO:ncn.evaluation:Lowest scores: tensor([ 9.7356, 14.9396, 15.8748, 16.0591, 16.2996, 16.5652, 17.5519, 19.1833,
#         19.9730, 20.7309])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([ 87,  97, 178, 252, 197,  95, 144, 122, 127, 203])
# INFO:ncn.evaluation:Lowest scores: tensor([ 8.5461, 10.3542, 11.0788, 11.3578, 11.4127, 11.7208, 12.0514, 12.3201,
#         12.6588, 12.7596])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([169, 174, 167,  38,  63,  79, 126, 218, 171, 253])
# INFO:ncn.evaluation:Lowest scores: tensor([ 8.1867,  8.9959, 10.1810, 11.6646, 12.0407, 12.4905, 12.5711, 13.2129,
#         13.8984, 14.1093])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([246, 176, 193, 173, 247, 132, 148, 145, 194, 242])
# INFO:ncn.evaluation:Lowest scores: tensor([13.3463, 15.0048, 15.3302, 15.9180, 16.3359, 17.3037, 19.0221, 19.1248,
#         19.7017, 19.8701])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([209,  13,  74,  14, 206, 123, 182, 204, 170, 244])
# INFO:ncn.evaluation:Lowest scores: tensor([ 9.9606, 10.2128, 11.9024, 16.8468, 17.5343, 18.1552, 18.3288, 20.3391,
#         20.5903, 21.5420])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([132, 124, 231, 229, 189, 195,  30,  90,  69, 174])
# INFO:ncn.evaluation:Lowest scores: tensor([ 7.8385,  9.0034,  9.0147,  9.4728, 10.1039, 10.2445, 10.9036, 11.0377,
#         11.5404, 11.7147])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([179,   3,   5, 117, 256,  58, 136, 141,   0,  23])
# INFO:ncn.evaluation:Lowest scores: tensor([ 7.7509,  8.9672,  9.1155, 10.2183, 10.9413, 11.4302, 13.4461, 15.0374,
#         15.2335, 15.5873])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 1 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([127, 118, 244, 126, 106, 128, 219, 142, 162, 221])
# INFO:ncn.evaluation:Lowest scores: tensor([11.1509, 13.3182, 13.7955, 17.2563, 17.9840, 19.5874, 20.3331, 21.3652,
#         21.8199, 22.5359])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([ 56,   5, 155,  50,  57, 135,  60,  90,  48,  29])
# INFO:ncn.evaluation:Lowest scores: tensor([ 6.8883,  8.3003,  9.2940,  9.3703, 10.4447, 11.6956, 11.8904, 12.2081,
#         12.4071, 12.7248])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([219, 256, 100, 215,  21, 202, 124, 141, 130, 216])
# INFO:ncn.evaluation:Lowest scores: tensor([ 6.9869,  7.6039,  8.4648,  9.9117,  9.9593, 10.2826, 11.2451, 11.2873,
#         11.7259, 11.7574])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 1 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([ 75, 173,  14,  78, 127,  44, 149, 159,   0,  33])
# INFO:ncn.evaluation:Lowest scores: tensor([ 8.5247,  9.5708,  9.9777, 10.8467, 12.2129, 12.5255, 13.3834, 14.9033,
#         15.3706, 16.8701])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([164,  53,  51,   5, 180,  27,  55, 244, 181, 147])
# INFO:ncn.evaluation:Lowest scores: tensor([ 7.7398,  8.3698,  8.6854,  9.1335, 10.4164, 11.8538, 12.0173, 12.8596,
#         13.3467, 13.5259])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([228,  94,  38, 104, 231, 171, 163,  70, 101, 229])
# INFO:ncn.evaluation:Lowest scores: tensor([14.1559, 14.2562, 14.2764, 15.2833, 15.6600, 15.8770, 15.9032, 16.9894,
#         17.2267, 18.2493])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([ 65, 151, 163,  62,  29,  28,  61, 252, 104, 148])
# INFO:ncn.evaluation:Lowest scores: tensor([ 9.0637,  9.4037, 11.7820, 11.7973, 12.3024, 13.8153, 14.2584, 14.5626,
#         14.6935, 15.3587])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([168, 185, 108, 195, 147, 104,   0, 207, 229,  84])
# INFO:ncn.evaluation:Lowest scores: tensor([ 9.8920, 14.9669, 15.2052, 15.4009, 15.9464, 17.3050, 17.3620, 17.9500,
#         18.4405, 19.8290])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([ 40, 154, 212, 233, 250,  18,  73, 129, 249,  42])
# INFO:ncn.evaluation:Lowest scores: tensor([ 9.2435,  9.8908, 10.2672, 10.5959, 10.6761, 10.7419, 11.6786, 11.7400,
#         13.0521, 13.1485])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([257])
# INFO:ncn.evaluation:Index: tensor([  3,  13,  10,  20,  58, 115,  86,  25,  54,  61])
# INFO:ncn.evaluation:Lowest scores: tensor([ 9.4542, 11.9365, 15.5160, 16.5583, 20.6807, 20.7116, 21.5328, 21.8402,
#         21.8631, 22.1538])
# INFO:ncn.evaluation:Range of true titles: 256 - 255
# INFO:ncn.evaluation:Scored 0 out of 1 titles at 10.
# INFO:ncn.evaluation:Evaluation scores shape: torch.Size([259])
# INFO:ncn.evaluation:Index: tensor([199, 246, 173, 196, 123, 116, 229, 147, 106, 214])
# INFO:ncn.evaluation:Lowest scores: tensor([ 9.6503, 10.2090, 11.9422, 13.8992, 14.6530, 15.1478, 17.5196, 17.9371,
#         18.0503, 18.0870])
# INFO:ncn.evaluation:Range of true titles: 258 - 255
# INFO:ncn.evaluation:Scored 0 out of 3 titles at 10.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-a0a29eebb178> in <module>
# ----> 1 at_10 = evaluator.recall(10)
#
# d:\Thi.DN\PhD\ThayBay\GCN\ebookML_src-master\src\neural_citation-master\ncn\evaluation.py in recall(self, x)
#     241                 #logger.debug(f"Evaluation title shapes: {titles.shape}")
#     242
# --> 243                 scores = self.criterion(output, titles)
#     244                 scores = scores.sum(dim=1)
#     245                 logger.info(f"Evaluation scores shape: {scores.shape}")
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\loss.py in forward(self, input, target)
#     959
#     960     def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 961         return F.cross_entropy(input, target, weight=self.weight,
#     962                                ignore_index=self.ignore_index, reduction=self.reduction)
#     963
#
# ~\Anaconda3\lib\site-packages\torch\nn\functional.py in cross_entropy(input, target, weight, size_average, ignore_index, reduce, reduction)
#    2466     if size_average is not None or reduce is not None:
#    2467         reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 2468     return nll_loss(log_softmax(input, 1), target, weight, None, ignore_index, None, reduction)
#    2469
#    2470
#
# ~\Anaconda3\lib\site-packages\torch\nn\functional.py in log_softmax(input, dim, _stacklevel, dtype)
#    1603         dim = _get_softmax_dim('log_softmax', input.dim(), _stacklevel)
#    1604     if dtype is None:
# -> 1605         ret = input.log_softmax(dim)
#    1606     else:
#    1607         ret = input.log_softmax(dim, dtype=dtype)
#
# KeyboardInterrupt:

# %%
round(at_10, 4)
# Out:
# 0.0577
